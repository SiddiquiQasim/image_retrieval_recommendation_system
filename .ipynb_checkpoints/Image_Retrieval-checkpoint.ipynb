# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# %%
class data_manager():

  def __init__(self, data='cars196', vgg_preprocess=True):

    self.dataset, self.dataset_info = tfds.load(data, with_info=True, as_supervised=True)
    self.vgg_preprocess = vgg_preprocess

  def preprocess_fn(self, image, label):
    
    image = tf.image.resize(image, (224, 224))
    if self.vgg_preprocess:
      image = tf.keras.applications.vgg16.preprocess_input(image)
    label = tf.one_hot(tf.cast(label, tf.int32), depth=self.dataset_info.features["label"].num_classes)
    return image, label


  def load_data(self, batch_size=1, split=True):

    if split:
      train_dataset, test_dataset = self.dataset['train'], self.dataset['test']
      train_dataset = train_dataset.map(self.preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE)
      test_dataset = test_dataset.map(self.preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE)
      return train_dataset.batch(batch_size), test_dataset.batch(batch_size), self.dataset_info
    else:
      self.train_dataset = self.dataset['train']
      train_dataset = self.train_dataset.map(self.preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE)
      return train_dataset.batch(batch_size), self.dataset_info

# data = data_manager(data='cars196', vgg_preprocess=True)
# train_dataset, test_dataset, dataset_info = data.load_data(batch_size=32, split=True)

# %%
class VGG16():
  def __init__(self,dataset_info, weights='imagenet', include_top=False, input_shape=(224,224,3)):
    self.dataset_info = dataset_info
    self.weights = weights
    self.include_top = include_top
    self.input_shape = input_shape

  def build_embedding(self, all_par=True):
    if all_par:
      emb_input = tf.keras.layers.Input(shape=self.input_shape)
      vgg16 = tf.keras.applications.VGG16(weights=self.weights, include_top=self.include_top, input_shape=self.input_shape)(emb_input)
      x = tf.keras.layers.GlobalAveragePooling2D()(vgg16)
      emb = tf.keras.layers.Dense(512, activation='relu')(x)

      embedding = tf.keras.Model(inputs=[emb_input], outputs=[emb])

    else:
      emb_input = tf.keras.layers.Input(shape=self.input_shape)
      vgg16 = tf.keras.applications.VGG16(weights=self.weights, include_top=self.include_top, input_shape=self.input_shape)
      for layer in vgg16.layers:
        layer.trainable = False
      vgg16 = vgg16(emb_input)
      x = tf.keras.layers.GlobalAveragePooling2D()(vgg16)
      emb = tf.keras.layers.Dense(512, activation='relu')(x)

      embedding = tf.keras.Model(inputs=[emb_input], outputs=[emb])

    return embedding


  def train(self, train_dataset, epochs, all_par):

    embedding = self.build_embedding(all_par=all_par)

    input = tf.keras.layers.Input(shape=self.input_shape)
    emb = embedding(input)
    output = tf.keras.layers.Dense(self.dataset_info.features["label"].num_classes, activation="softmax")(emb)
    model = tf.keras.Model(inputs=[input], outputs=[output])
    
    
    best_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath='/content/drive/MyDrive/img_ret/best_model_online.h5',
        save_best_only=True,
        save_weights_only=False,
        monitor='accuracy',
        mode='max',
        verbose=1)

    last_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
        filepath='/content/drive/MyDrive/img_ret/last_model_omline.h5',
        save_best_only=False,
        save_weights_only=False,
        monitor='accuracy',
        mode='max',
        verbose=1)
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    history = model.fit(train_dataset, epochs=epochs, batch_size=32, callbacks=[best_model_checkpoint, last_model_checkpoint])

    return model, embedding, history

  def image_embedding(self, embedding, train_dataset, test_dataset):
    
    train_emb = embedding.predict(train_dataset)
    test_emb = embedding.predict(test_dataset)

    return train_emb, test_emb

# vgg = VGG16(dataset_info)
# model, embedding, history = vgg.train(train_dataset, epochs=1, all_par=False)
# train_dataset, test_dataset, dataset_info = data.load_data(batch_size=1, split=True)
# image_embedding(self, embedding, train_dataset, test_dataset)

# %%
class inference():

  def __init__(self, data='cars196', vgg_preprocess=False):

    data = data_manager(data=data, vgg_preprocess=vgg_preprocess)
    self.train_dataset, self.test_dataset, self.dataset_info = data.load_data(batch_size=1, split=True)

  def nearest_neighbors(self, train_emb, test_emb, test_idx, n_neighbors=5):

    knn = NearestNeighbors(metric="euclidean")
    knn.fit(train_emb)
    (neighbors_dist,),(neighbors_idx,) = knn.kneighbors(np.reshape(test_emb[test_idx], (1,-1)), n_neighbors=n_neighbors)

    return neighbors_dist, neighbors_idx


  def retrieve_image(self, train_emb, test_emb, test_idx, n_neighbors=5):

    _, neighbors_idx = self.nearest_neighbors(train_emb, test_emb, test_idx, n_neighbors=5)

    for k, test_example in enumerate(self.test_dataset):
      if k == test_idx:
        image, label = test_example
        plt.figure(figsize=[16,14])
        plt.subplot(n_neighbors+1,1,1)
        plt.imshow(np.clip(image[0], 0,255) / 255)
        plt.axis('off')
        plt.title("Original{}:{}".format(np.where(label[0]==1)[0], self.dataset_info.features['label'].names[np.where(label[0]==1)[0][0]]))

        break
    for j in range(len(neighbors_idx)):
      for i, example in enumerate(self.train_dataset):
        if i == neighbors_idx[j]:
          image, label = example
          plt.subplot(n_neighbors+1,1,j+2)
          plt.imshow(np.clip(image[0], 0,255) / 255)
          plt.axis('off')
          plt.title("Recommend{}:{}".format(np.where(label[0]==1)[0], self.dataset_info.features['label'].names[np.where(label[0]==1)[0][0]]))
          break


  def precision_recall(self, train_emb, test_emb, n_neighbors=5):
    tp = 0
    for test_idx, test_example in enumerate(self.test_dataset):
      _, neighbors_idx = self.nearest_neighbors(train_emb, test_emb, test_idx, n_neighbors=5)
      _, test_label = test_example
      test_label = np.where(test_label[0]==1)[0][0]
      for j in range(len(neighbors_idx)):
        for i, example in enumerate(self.train_dataset):
          if i == neighbors_idx[j]:
            _, label = example
            label = np.where(label[0]==1)[0][0]
            if test_label == label:
              tp += 1
            break
    return tp/(n_neighbors*(test_idx+1)), tp/(test_idx+1)
# visualize = image_retreival()
# train_emb, test_emb = viaulaize.image_embedding(embedding)
# visualize.retrieve_image(self, train_emb, test_emb, test_idx, n_neighbors=5)

# %%
data = data_manager(data='cars196', vgg_preprocess=True)
train_dataset, test_dataset, dataset_info = data.load_data(batch_size=32, split=True)
# Out:
# Downloading and preparing dataset 1.82 GiB (download: 1.82 GiB, generated: 1.85 GiB, total: 3.68 GiB) to /root/tensorflow_datasets/cars196/2.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/8144 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/cars196/2.1.0.incompleteA876NP/cars196-train.tfrecord*...:   0%|          …
# Generating test examples...:   0%|          | 0/8041 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/cars196/2.1.0.incompleteA876NP/cars196-test.tfrecord*...:   0%|          |…
# Dataset cars196 downloaded and prepared to /root/tensorflow_datasets/cars196/2.1.0. Subsequent calls will reuse this data.

# %%
vgg = VGG16(dataset_info, weights='imagenet', include_top=False, input_shape=(224,224,3))
model, embedding, history = vgg.train(train_dataset, epochs=20, all_par=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/20
# 255/255 [==============================] - ETA: 0s - loss: 5.0649 - accuracy: 0.0636 - precision: 0.2449 - recall: 0.0074 - auc: 0.7101
# Epoch 1: accuracy improved from -inf to 0.06361, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 1: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 60s 184ms/step - loss: 5.0649 - accuracy: 0.0636 - precision: 0.2449 - recall: 0.0074 - auc: 0.7101
# Epoch 2/20
# 255/255 [==============================] - ETA: 0s - loss: 2.9868 - accuracy: 0.2798 - precision: 0.7150 - recall: 0.1029 - auc: 0.9223
# Epoch 2: accuracy improved from 0.06361 to 0.27984, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 2: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 56s 220ms/step - loss: 2.9868 - accuracy: 0.2798 - precision: 0.7150 - recall: 0.1029 - auc: 0.9223
# Epoch 3/20
# 255/255 [==============================] - ETA: 0s - loss: 1.9871 - accuracy: 0.4894 - precision: 0.8284 - recall: 0.2692 - auc: 0.9688
# Epoch 3: accuracy improved from 0.27984 to 0.48944, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 3: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 59s 231ms/step - loss: 1.9871 - accuracy: 0.4894 - precision: 0.8284 - recall: 0.2692 - auc: 0.9688
# Epoch 4/20
# 255/255 [==============================] - ETA: 0s - loss: 1.3642 - accuracy: 0.6426 - precision: 0.8835 - recall: 0.4416 - auc: 0.9844
# Epoch 4: accuracy improved from 0.48944 to 0.64256, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 4: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 63s 246ms/step - loss: 1.3642 - accuracy: 0.6426 - precision: 0.8835 - recall: 0.4416 - auc: 0.9844
# Epoch 5/20
# 255/255 [==============================] - ETA: 0s - loss: 0.9496 - accuracy: 0.7495 - precision: 0.9160 - recall: 0.5888 - auc: 0.9920
# Epoch 5: accuracy improved from 0.64256 to 0.74951, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 5: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 47s 184ms/step - loss: 0.9496 - accuracy: 0.7495 - precision: 0.9160 - recall: 0.5888 - auc: 0.9920
# Epoch 6/20
# 255/255 [==============================] - ETA: 0s - loss: 0.6882 - accuracy: 0.8193 - precision: 0.9268 - recall: 0.6970 - auc: 0.9963
# Epoch 6: accuracy improved from 0.74951 to 0.81925, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 6: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 46s 179ms/step - loss: 0.6882 - accuracy: 0.8193 - precision: 0.9268 - recall: 0.6970 - auc: 0.9963
# Epoch 7/20
# 255/255 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.8697 - precision: 0.9437 - recall: 0.7797 - auc: 0.9985
# Epoch 7: accuracy improved from 0.81925 to 0.86972, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 7: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 46s 180ms/step - loss: 0.4877 - accuracy: 0.8697 - precision: 0.9437 - recall: 0.7797 - auc: 0.9985
# Epoch 8/20
# 255/255 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.9090 - precision: 0.9540 - recall: 0.8403 - auc: 0.9992
# Epoch 8: accuracy improved from 0.86972 to 0.90901, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 8: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 45s 176ms/step - loss: 0.3609 - accuracy: 0.9090 - precision: 0.9540 - recall: 0.8403 - auc: 0.9992
# Epoch 9/20
# 255/255 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.9280 - precision: 0.9588 - recall: 0.8825 - auc: 0.9995
# Epoch 9: accuracy improved from 0.90901 to 0.92805, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 9: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 45s 175ms/step - loss: 0.2880 - accuracy: 0.9280 - precision: 0.9588 - recall: 0.8825 - auc: 0.9995
# Epoch 10/20
# 255/255 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9440 - precision: 0.9653 - recall: 0.9118 - auc: 0.9995
# Epoch 10: accuracy improved from 0.92805 to 0.94401, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 10: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 46s 178ms/step - loss: 0.2222 - accuracy: 0.9440 - precision: 0.9653 - recall: 0.9118 - auc: 0.9995
# Epoch 11/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9570 - precision: 0.9709 - recall: 0.9338 - auc: 0.9995
# Epoch 11: accuracy improved from 0.94401 to 0.95702, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 11: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 46s 178ms/step - loss: 0.1748 - accuracy: 0.9570 - precision: 0.9709 - recall: 0.9338 - auc: 0.9995
# Epoch 12/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9686 - precision: 0.9792 - recall: 0.9521 - auc: 0.9997
# Epoch 12: accuracy improved from 0.95702 to 0.96857, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 12: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 46s 179ms/step - loss: 0.1369 - accuracy: 0.9686 - precision: 0.9792 - recall: 0.9521 - auc: 0.9997
# Epoch 13/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9710 - precision: 0.9774 - recall: 0.9608 - auc: 0.9996
# Epoch 13: accuracy improved from 0.96857 to 0.97102, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 13: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 45s 177ms/step - loss: 0.1200 - accuracy: 0.9710 - precision: 0.9774 - recall: 0.9608 - auc: 0.9996
# Epoch 14/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.9665 - precision: 0.9747 - recall: 0.9570 - auc: 0.9996
# Epoch 14: accuracy did not improve from 0.97102
#
# Epoch 14: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 44s 172ms/step - loss: 0.1211 - accuracy: 0.9665 - precision: 0.9747 - recall: 0.9570 - auc: 0.9996
# Epoch 15/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9681 - precision: 0.9749 - recall: 0.9583 - auc: 0.9994
# Epoch 15: accuracy did not improve from 0.97102
#
# Epoch 15: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 44s 172ms/step - loss: 0.1204 - accuracy: 0.9681 - precision: 0.9749 - recall: 0.9583 - auc: 0.9994
# Epoch 16/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9713 - precision: 0.9779 - recall: 0.9622 - auc: 0.9993
# Epoch 16: accuracy improved from 0.97102 to 0.97127, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 16: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 45s 176ms/step - loss: 0.1155 - accuracy: 0.9713 - precision: 0.9779 - recall: 0.9622 - auc: 0.9993
# Epoch 17/20
# 255/255 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9753 - precision: 0.9808 - recall: 0.9704 - auc: 0.9995
# Epoch 17: accuracy improved from 0.97127 to 0.97532, saving model to /content/drive/MyDrive/img_ret/best_model_online.h5
#
# Epoch 17: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 45s 176ms/step - loss: 0.0960 - accuracy: 0.9753 - precision: 0.9808 - recall: 0.9704 - auc: 0.9995
# Epoch 18/20
# 255/255 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9732 - precision: 0.9785 - recall: 0.9657 - auc: 0.9993
# Epoch 18: accuracy did not improve from 0.97532
#
# Epoch 18: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 44s 172ms/step - loss: 0.0970 - accuracy: 0.9732 - precision: 0.9785 - recall: 0.9657 - auc: 0.9993
# Epoch 19/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9645 - precision: 0.9715 - recall: 0.9574 - auc: 0.9991
# Epoch 19: accuracy did not improve from 0.97532
#
# Epoch 19: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 44s 173ms/step - loss: 0.1169 - accuracy: 0.9645 - precision: 0.9715 - recall: 0.9574 - auc: 0.9991
# Epoch 20/20
# 255/255 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9605 - precision: 0.9668 - recall: 0.9538 - auc: 0.9990
# Epoch 20: accuracy did not improve from 0.97532
#
# Epoch 20: saving model to /content/drive/MyDrive/img_ret/last_model_omline.h5
# 255/255 [==============================] - 44s 173ms/step - loss: 0.1375 - accuracy: 0.9605 - precision: 0.9668 - recall: 0.9538 - auc: 0.9990

# %%
train_dataset, test_dataset, dataset_info = data.load_data(batch_size=1, split=True)
train_emb, test_emb = vgg.image_embedding(embedding, train_dataset, test_dataset)
# Out:
# 8144/8144 [==============================] - 72s 9ms/step
# 8041/8041 [==============================] - 70s 9ms/step

# %%
inf = inference(data='cars196', vgg_preprocess=False)

# %%
inf.retrieve_image(train_emb, test_emb, test_idx=55, n_neighbors=5)

# %%
inf.retrieve_image(train_emb, test_emb, test_idx=250, n_neighbors=5)

# %%
inf.retrieve_image(train_emb, test_emb, test_idx=7500, n_neighbors=5)

# %%
precision, recall = inf.precision_recall(train_emb, test_emb, n_neighbors=5)

# %%
print("Precision : {}".format(precision))
print("Recall : {}".format(recall))
